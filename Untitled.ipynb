# %%
#!pip install tensorflow pandas streamlit numpy matplot

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from keras import layers

# %%
data_train_path = "Split_smol/train"
data_train_test = "Split_smol/test" 
data_train_val = "Split_smol/val"

# %%
img_width = 160
img_height = 160

# %%
data_train = tf.keras.utils.image_dataset_from_directory(
    data_train_path,
    shuffle = True,
    image_size = (img_width, img_height),
    batch_size = 32,
    validation_split = False
)
# Out:
# Found 799 files belonging to 10 classes.

# %%
data_cat = data_train.class_names

# %%
data_val = tf.keras.utils.image_dataset_from_directory(
    data_train_val,
    shuffle = False,
    image_size = (img_width, img_height),
    batch_size = 32,
    validation_split = False

)
# Out:
# Found 198 files belonging to 10 classes.

# %%
data_test = tf.keras.utils.image_dataset_from_directory(
    data_train_test,
    shuffle = False,
    image_size = (img_width, img_height),
    batch_size = 32,
    validation_split = False
)
# Out:
# Found 51 files belonging to 10 classes.

# %%
plt.figure(figsize=(10,10))
for image , labels in data_train.take(1):
    for i in range(9):
        plt.subplot(3,3,i+1)
        plt.imshow(image[i].numpy().astype('uint8'))
        plt.title(data_cat[labels[i]])
        plt.axis('off')

# %%
from keras.models import Sequential

# %%
model = Sequential([
    layers.Rescaling(1./255),
    layers.Conv2D(16, 3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(32, 3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(64, 3, padding = 'same', activation = 'relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dropout(0.2),
    layers.Dense(128),
    layers.Dense(len(data_cat))
])

# %%
model.compile(optimizer = 'adam' , loss = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True), metrics = ['accuracy'])

# %%
history = model.fit(data_train, validation_data = data_val , epochs = 25)
# Out:
# Epoch 1/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 339ms/step - accuracy: 0.1239 - loss: 4.9870 - val_accuracy: 0.1212 - val_loss: 2.1638
# Epoch 2/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 366ms/step - accuracy: 0.2640 - loss: 1.9792 - val_accuracy: 0.4394 - val_loss: 1.7260
# Epoch 3/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 364ms/step - accuracy: 0.4706 - loss: 1.5151 - val_accuracy: 0.4495 - val_loss: 1.5807
# Epoch 4/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 354ms/step - accuracy: 0.5900 - loss: 1.1697 - val_accuracy: 0.5202 - val_loss: 1.3410
# Epoch 5/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 350ms/step - accuracy: 0.5830 - loss: 1.0815 - val_accuracy: 0.4798 - val_loss: 1.4853
# Epoch 6/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - accuracy: 0.6375 - loss: 0.9428 - val_accuracy: 0.6212 - val_loss: 1.2555
# Epoch 7/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 343ms/step - accuracy: 0.7126 - loss: 0.7495 - val_accuracy: 0.5707 - val_loss: 1.5034
# Epoch 8/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 359ms/step - accuracy: 0.6975 - loss: 0.8068 - val_accuracy: 0.6263 - val_loss: 1.2375
# Epoch 9/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 367ms/step - accuracy: 0.7829 - loss: 0.6282 - val_accuracy: 0.6111 - val_loss: 1.2172
# Epoch 10/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 346ms/step - accuracy: 0.7929 - loss: 0.5598 - val_accuracy: 0.6212 - val_loss: 1.3083
# Epoch 11/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 361ms/step - accuracy: 0.7641 - loss: 0.5679 - val_accuracy: 0.6162 - val_loss: 1.3390
# Epoch 12/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 374ms/step - accuracy: 0.8008 - loss: 0.5723 - val_accuracy: 0.6061 - val_loss: 1.3873
# Epoch 13/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 10s 370ms/step - accuracy: 0.8555 - loss: 0.4406 - val_accuracy: 0.6162 - val_loss: 1.5930
# Epoch 14/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 359ms/step - accuracy: 0.8630 - loss: 0.3878 - val_accuracy: 0.6162 - val_loss: 1.4211
# Epoch 15/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 374ms/step - accuracy: 0.8736 - loss: 0.3719 - val_accuracy: 0.6010 - val_loss: 1.6252
# Epoch 16/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 356ms/step - accuracy: 0.8937 - loss: 0.3703 - val_accuracy: 0.6111 - val_loss: 1.5399
# Epoch 17/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 365ms/step - accuracy: 0.9151 - loss: 0.2797 - val_accuracy: 0.6263 - val_loss: 1.7364
# Epoch 18/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 369ms/step - accuracy: 0.9016 - loss: 0.3158 - val_accuracy: 0.6667 - val_loss: 1.5146
# Epoch 19/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 366ms/step - accuracy: 0.8953 - loss: 0.2689 - val_accuracy: 0.6364 - val_loss: 1.6148
# Epoch 20/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 357ms/step - accuracy: 0.9181 - loss: 0.2506 - val_accuracy: 0.6515 - val_loss: 1.7144
# Epoch 21/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 9s 364ms/step - accuracy: 0.9373 - loss: 0.1965 - val_accuracy: 0.6414 - val_loss: 1.9277
# Epoch 22/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 18s 691ms/step - accuracy: 0.9679 - loss: 0.1258 - val_accuracy: 0.6566 - val_loss: 1.8048
# Epoch 23/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 20s 684ms/step - accuracy: 0.9750 - loss: 0.1149 - val_accuracy: 0.6818 - val_loss: 2.4134
# Epoch 24/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 17s 676ms/step - accuracy: 0.9550 - loss: 0.1450 - val_accuracy: 0.6667 - val_loss: 2.2070
# Epoch 25/25
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 21s 676ms/step - accuracy: 0.9793 - loss: 0.1015 - val_accuracy: 0.6465 - val_loss: 2.4245

# %%
data_val
# Out:
# <_PrefetchDataset element_spec=(TensorSpec(shape=(None, 160, 160, 3), dtype=tf.float32, name=None), TensorSpec(shape=(None,), dtype=tf.int32, name=None))>

# %%
epochs_range = range(25)
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(epochs_range,history.history['accuracy'],label = 'Training Accuracy')
plt.plot(epochs_range,history.history['val_accuracy'],label = 'Validation Accuracy')
plt.title('Accuracy')

plt.subplot(1,2,2)
plt.plot(epochs_range,history.history['loss'],label = 'Training Loss')
plt.plot(epochs_range,history.history['val_loss'],label = 'Validation Loss')
plt.title('Loss')
# Out:
# Text(0.5, 1.0, 'Loss')

# %%
image = '1.jpeg'
image = tf.keras.utils.load_img(image , target_size = (img_height, img_width))
img_arr = tf.keras.utils.array_to_img(image)
img_bat = tf.expand_dims(img_arr,0)

# %%
predict = model.predict(img_bat)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step

# %%
score = tf.nn.softmax(predict)

# %%
print("Skin Disease in the image is {} with an accuracy of {:0.2f}".format(data_cat[np.argmax(score)],np.max(score)*100))
# Out:
# Skin Disease in the image is Atopic Dermatitis with an accuracy of 100.00

# %%
model.save('Skin_disease1.keras')

# %%
data_cat
# Out:
# ['Actinic keratosis',
#  'Atopic Dermatitis',
#  'Benign keratosis',
#  'Dermatofibroma',
#  'Melanocytic nevus',
#  'Melanoma',
#  'Squamous cell carcinoma',
#  'Tinea Ringworm Candidiasis',
#  'Vascular lesion',
#  'normal skin']
